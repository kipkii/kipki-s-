# %% [markdown]
# <a href="https://colab.research.google.com/github/kipkii/kipki-s-/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
gdown.download('https://bit.ly/3736JW1','ns_book7.csv',quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3736JW1
# To: /content/ns_book7.csv
# 100%|██████████| 55.0M/55.0M [00:00<00:00, 86.3MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사    발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021.0  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021.0  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021.0  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021.0  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021.0  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
import matplotlib.pyplot as plt


plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha =0.1)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha=0.1)
plt.show()

# %%
plt.figure(figsize=(900/72, 600/72))
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha= 0.1)
plt.show()

# %%
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': None}
plt.figure(figsize=(900/72, 600/72))
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1)
plt.show()

# %%
# %config InlineBackend.print_figure_kwargs = {'bbox_inches': 'tight'}
plt.figure(figsize=(900/72, 600/72))
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1)
plt.show()

# %%
plt.figure(dpi=144)
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1)
plt.show()

# %%
plt.rcParams['figure.dpi'] = 100

# %%
plt.rcParams['scatter.marker']
# Out:
# 'o'

# %%
plt.rcParams['scatter.marker'] = '*'

# %%
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1)
plt.show()

# %%
plt.scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1, marker='+')
plt.show()

# %%
fig, axs = plt.subplots(2)

axs[0].scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha = 0.1)

axs[1].hist(ns_book7['대출건수'], bins=100)
axs[1].set_yscale('log')

fig.show()

# %%
fig,axs = plt.subplots(2, figsize = (6,8))

axs[0].scatter(ns_book7['대출건수'], ns_book7['대출건수'], alpha=0.1)
axs[0].set_title('scatter plot')

axs[1].hist(ns_book7['대출건수'], bins=100)
axs[1].set_title('histogram')
axs[1].set_yscale('log')

fig.show()

# %%
fig, axs = plt.subplots(1,2, figsize = (10,4))

axs[0].scatter(ns_book7['도서권수'], ns_book7['대출건수'], alpha=0.1)
axs[0].set_title('scatter plot')
axs[0].set_xlabel('number of books')
axs[0].set_ylabel  ('borrow count')

axs[1].hist(ns_book7['대출건수'], bins = 100)
axs[1].set_title('histogram')
axs[1].set_yscale('log')
axs[1].set_xlabel('borrow count')
axs[1].set_ylabel('frequency')

fig.show()

# %%
import gdown
gdown.download('https://bit.ly/3736JW1','ns_book7.csv',quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3736JW1
# To: /content/ns_book7.csv
# 100%|██████████| 55.0M/55.0M [00:00<00:00, 68.9MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사    발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021.0  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021.0  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021.0  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021.0  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021.0  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
count_by_year = ns_book7['발행년도'].value_counts()
count_by_year
# Out:
# 발행년도
# 2012.0    18633
# 2014.0    17820
# 2009.0    17683
# 2011.0    17552
# 2010.0    17545
#           ...
# 2548.0        1
# 1948.0        1
# 1967.0        1
# 2542.0        1
# 1947.0        1
# Name: count, Length: 87, dtype: int64

# %%
count_by_year = count_by_year.sort_index()
count_by_year
# Out:
# 발행년도
# 1947.0     1
# 1948.0     1
# 1949.0     1
# 1952.0    11
# 1954.0     1
#           ..
# 2551.0     1
# 2552.0     2
# 2559.0     1
# 2560.0     1
# 2650.0     1
# Name: count, Length: 87, dtype: int64

# %%
count_by_year = count_by_year[count_by_year.index <= 2030]
count_by_year
# Out:
# 발행년도
# 1947.0        1
# 1948.0        1
# 1949.0        1
# 1952.0       11
# 1954.0        1
#           ...
# 2020.0    12027
# 2021.0     1276
# 2025.0        1
# 2028.0        1
# 2030.0        1
# Name: count, Length: 68, dtype: int64

# %%
import numpy as np

def kdc_1st_char(no):
  if no is np.nan:
    return '-1'
  else:
    return no[0]


count_by_subject = ns_book7['주제분류번호'].apply(kdc_1st_char).value_counts()
count_by_subject
# Out:
# 주제분류번호
# 8     108835
# 3      80794
# 5      40928
# 9      26444
# 6      25110
# 1      22661
# -1     19729
# 7      15884
# 4      13702
# 2      13477
# 0      12412
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100

# %%
plt.plot(count_by_year.index, count_by_year.values)
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year,
         marker='.',
         linestyle=':',
         color='red')
plt.title("Books by year")
plt.xlabel('year')
plt.ylabel('number fo books')
plt.show()

# %%
plt.plot(count_by_year, '.:r')

# %%
plt.plot(count_by_year,
         '*-g')
plt.title("Books by year")
plt.xlabel('year')
plt.ylabel('number fo books')
plt.show()

# %%
plt.plot(count_by_year,
         '*-g')
plt.title("Books by year")
plt.xlabel('year')
plt.ylabel('number fo books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
  plt.annotate(val, (idx,val))
plt.show()

# %%
plt.plot(count_by_year,
         '*-g')
plt.title("Books by year")
plt.xlabel('year')
plt.ylabel('number fo books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
  plt.annotate(val, (idx,val), xytext=(idx+1, val+10))
plt.show()

# %%
plt.plot(count_by_year,
         '*-g')
plt.title("Books by year")
plt.xlabel('year')
plt.ylabel('number fo books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
  plt.annotate(val, (idx,val), xytext=(2, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values)
plt.title('Books by subject')
plt.xlabel('subject')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
  plt.annotate(val, (idx,val), xytext=(0,2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values, width=0.7, color= 'blue')
plt.title('Books by subject')
plt.xlabel('subject')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
  plt.annotate(val, (idx,val), xytext=(0,2), textcoords='offset points',
               fontsize=8, ha='center', color='green')
plt.show()

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7,color= 'blue')
plt.title('Books by subject')
plt.xlabel('number of books')
plt.ylabel('subject')
for idx, val in count_by_subject.items():
  plt.annotate(val, (val,idx), xytext=(2,0), textcoords='offset points',
               fontsize=8, va='center', color='green')
plt.show()

# %%
import sys
if 'google.colab' in sys.modules:
  # !wget https://bit.ly/3wrj4xf -O jupiter.png
# Out:
# --2026-05-20 10:06:55--  https://bit.ly/3wrj4xf
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://raw.githubusercontent.com/rickiepark/hg-da/main/jupiter.png [following]
# --2026-05-20 10:06:55--  https://raw.githubusercontent.com/rickiepark/hg-da/main/jupiter.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3287363 (3.1M) [image/png]
# Saving to: ‘jupiter.png’
#
# jupiter.png         100%[===================>]   3.13M  --.-KB/s    in 0.07s
#
# 2026-05-20 10:06:55 (47.2 MB/s) - ‘jupiter.png’ saved [3287363/3287363]

# %%
img = plt.imread('jupiter.png')
img.shape
# Out:
# (1561, 1646, 3)

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
plt.imsave('jupiter.jpg', arr_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_526/3714868038.py in <cell line: 0>()
# ----> 1 plt.imsave('jupiter.jpg', arr_img)
#
# NameError: name 'arr_img' is not defined

# %%
plt.rcParams['savefig.dpi']
# Out:
# 'figure'

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7,color= 'blue')
plt.title('Books by subject')
plt.xlabel('number of books')
plt.ylabel('subject')
for idx, val in count_by_subject.items():
  plt.annotate(val, (val,idx), xytext=(2,0), textcoords='offset points',
               fontsize=8, va='center', color='green')
plt.savefig('books_by_subject.png')
plt.show()

# %%
from PIL import Image

pil_img = Image.open('books_by_subject.png')

plt.figure(figsize=(8,6))
plt.imshow(pil_img)
plt.axis('off')
plt.show()
