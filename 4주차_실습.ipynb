# %% [markdown]
# <a href="https://colab.research.google.com/github/kipkii/kipki-s-/blob/main/4%EC%A3%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 안녕하세요
# ## 안녕하세요
# ### 안녕하세요
# #### 안녕하세요
# ##### 안녕하세요
# ** 안녕하세요 **
# *안녕하세요*
# _안녕하세요_
# ~~안녕하세요~~
# >안녕하세요
# * 안녕하세요
# - 안녕하세요
# [한빛미디어](https://www.hanbit.co.kr/)
#
# ![한빛미디어](https://cdn-prod.hanbit.co.kr/images/store/logo_hanbit_plus.png)
#
# $ y=x /times z$

# %%
print("hello World")
# Out:
# hello World

# %%
seconds_in_a_week = 24*60*60*7
seconds_in_a_week
# Out:
# 604800
